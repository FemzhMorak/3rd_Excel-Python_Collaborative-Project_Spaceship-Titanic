# %%
# Getting & Prepping data
# - Import libraries (pandas, NumPy, matplotlib, seaborn, & warnings)
# - df (import file, describe, & info)
# ====================================================================================================

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('df_train.csv')
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.describe()
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
# Exploratory analysis
# - Seaborn (countplot, distplot, displot) & Maplotlib (plot, bar, pie)
# ====================================================================================================

#sns.countplot(df['HomePlanet'])
plt.subplot(1,2,1)
sns.countplot(x = 'HomePlanet', data=df).bar_label(ax.containers[0])

plt.subplot(1,2,2)
sns.countplot(x = 'CryoSleep', data=df).bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2131'), Text(0, 0, '4602'), Text(0, 0, '1759')]

# %%
sns.countplot(df['Cabin'])
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='count'>

# %%
plt.subplot(1,1,1)
sns.countplot(df['Destination']).bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2131'), Text(0, 0, '4602'), Text(0, 0, '1759')]

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.subplot(1,1,1)
sns.countplot(df['VIP']).bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2131'), Text(0, 0, '4602'), Text(0, 0, '1759')]

# %%
plt.subplot(1,2,1)
sns.distplot(df['RoomService'])

plt.subplot(1,2,2)
sns.distplot(df['FoodCourt'])

plt.subplot(1,3,3)
sns.distplot(df['ShoppingMall'])
# Out:
# <AxesSubplot:xlabel='ShoppingMall', ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.distplot(df['FoodCourt'])

plt.subplot(1,2,2)
sns.distplot(df['Spa'])
# Out:
# <AxesSubplot:xlabel='Spa', ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.distplot(df['VRDeck'])

plt.subplot(1,2,2)
sns.countplot(df['Transported']).bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2131'), Text(0, 0, '4602'), Text(0, 0, '1759')]
